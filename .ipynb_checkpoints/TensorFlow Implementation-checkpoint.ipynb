# %%
import numpy as np 
import pandas as pd 
import nltk 
import matplotlib.pyplot as plt
import seaborn as sns
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Michael/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
Coats = pd.read_table("Dan Coats.txt", header =None)
Coats.columns = ['text']
Coats['author'] = 'Dan Coats'

Mattis = pd.read_table("James Mattis.txt", header =None)
Mattis.columns = ['text']
Mattis['author'] = 'James Mattis'

Kelly = pd.read_table("John Kelly.txt", header =None)
Kelly.columns = ['text']
Kelly['author'] = 'John Kelly'

Hassett = pd.read_table("Kevin Hassett.txt", header =None)
Hassett.columns = ['text']
Hassett['author'] = 'Kevin Hassett'

Nielsen = pd.read_table("Kirstjen Nielsen.txt", header =None)
Nielsen.columns = ['text']
Nielsen['author'] = 'Kirstjen Nielsen'

Kudlow = pd.read_table("Larry Kudlow.txt", header =None)
Kudlow.columns = ['text']
Kudlow['author'] = 'Larry Kudlow'

Pence = pd.read_table("Mike Pence.txt", header =None)
Pence.columns = ['text']
Pence['author'] = 'Mike Pence'

Pompeo = pd.read_table("Mike Pompeo.txt", header =None)
Pompeo.columns = ['text']
Pompeo['author'] = 'Mike Pompeo'

# %%
train = pd.DataFrame()
train = pd.concat([Coats, Mattis,Kelly,Hassett,Nielsen,Kudlow,Pence,Pompeo])
train.drop(train.columns[[0]], axis=1)

# Convert the author strings into numbers
#train['author'] = train['author'].apply(lambda x: possibleAuthors[x])
#print(train)
# Out:
#          author
# 0     Dan Coats
# 1     Dan Coats
# 2     Dan Coats
# 3     Dan Coats
# 4     Dan Coats
# 5     Dan Coats
# 6     Dan Coats
# 7     Dan Coats
# 8     Dan Coats
# 9     Dan Coats
# 10    Dan Coats
# 11    Dan Coats
# 12    Dan Coats
# 13    Dan Coats
# 14    Dan Coats
# 15    Dan Coats
# 16    Dan Coats
# 17    Dan Coats
# 18    Dan Coats
# 19    Dan Coats
# 20    Dan Coats
# 21    Dan Coats
# 22    Dan Coats
# 23    Dan Coats
# 24    Dan Coats
# 25    Dan Coats
# 26    Dan Coats
# 27    Dan Coats
# 28    Dan Coats
# 29    Dan Coats
# ..          ...
# 43  Mike Pompeo
# 44  Mike Pompeo
# 45  Mike Pompeo
# 46  Mike Pompeo
# 47  Mike Pompeo
# 48  Mike Pompeo
# 49  Mike Pompeo
# 50  Mike Pompeo
# 51  Mike Pompeo
# 52  Mike Pompeo
# 53  Mike Pompeo
# 54  Mike Pompeo
# 55  Mike Pompeo
# 56  Mike Pompeo
# 57  Mike Pompeo
# 58  Mike Pompeo
# 59  Mike Pompeo
# 60  Mike Pompeo
# 61  Mike Pompeo
# 62  Mike Pompeo
# 63  Mike Pompeo
# 64  Mike Pompeo
# 65  Mike Pompeo
# 66  Mike Pompeo
# 67  Mike Pompeo
# 68  Mike Pompeo
# 69  Mike Pompeo
# 70  Mike Pompeo
# 71  Mike Pompeo
# 72  Mike Pompeo
#
# [847 rows x 1 columns]

# %%
print(train)
# Out:
#                                                  text       author
# 0   Good evening, and sincere thanks to the Atlant...    Dan Coats
# 1   I enjoyed catching up with Atlantic council bo...    Dan Coats
# 2   Jeff Gedmin and I were also able to spend a fe...    Dan Coats
# 3   Last but certainly not least I would like to  ...    Dan Coats
# 4   So if you don’t like or agree with my remarks ...    Dan Coats
# 5   There is no better venue to address the issue ...    Dan Coats
# 6   Duty prevented me from attending the D-Day cer...    Dan Coats
# 7   And a century before that, Normandy was home t...    Dan Coats
# 8   The writings of Alexis De Tocqueville and the ...    Dan Coats
# 9   As a stranger in a strange land, his insights ...    Dan Coats
# 10  For the rest of the world—including his fellow...    Dan Coats
# 11  I can’t help but wonder what Tocqueville would...    Dan Coats
# 12  To be sure, he would see a democracy that is m...    Dan Coats
# 13  But Tocqueville would also see that our democr...    Dan Coats
# 14  Together we have successfully met these challe...    Dan Coats
# 15  My purpose at this conference is to explore ho...    Dan Coats
# 16  I’ll approach this question through the lens o...    Dan Coats
# 17  In my current position, my responsibility is t...    Dan Coats
# 18  Frankly, I welcome this limitation.  As a form...    Dan Coats
# 19  So in the context of my current position, I’ll...    Dan Coats
# 20  One is the foundational role of intelligence i...    Dan Coats
# 21  And the second is the importance of enduring r...    Dan Coats
# 22  As I see every day in our intelligence reports...    Dan Coats
# 23  From Russia’s renewed aggression, to China’s g...    Dan Coats
# 24  In addressing these threats, our role in the I...    Dan Coats
# 25  It requires that we produce objective, unvarni...    Dan Coats
# 26  And it requires that we tune out the daily pol...    Dan Coats
# 27  In our business, we must adhere to the very fo...    Dan Coats
# 28  By that I mean we must seek and speak the trut...    Dan Coats
# 29  I consistently remind our workforce to remain ...    Dan Coats
# ..                                                ...          ...
# 43  Inciting chants of “Death to America” and “Dea...  Mike Pompeo
# 44  Being the number one state sponsor of terror i...  Mike Pompeo
# 45  Sometimes it seems the world has become desens...  Mike Pompeo
# 46  And the United States under President Trump wi...  Mike Pompeo
# 47  In light of these protests and 40 years of reg...  Mike Pompeo
# 48  When the United States sees the shoots of libe...  Mike Pompeo
# 49  Right now, the United States is undertaking a ...  Mike Pompeo
# 50  At the center of this campaign is the re-impos...  Mike Pompeo
# 51  As we have explained over the last few weeks, ...  Mike Pompeo
# 52  Recently – (applause). Recently, as part of th...  Mike Pompeo
# 53  And there’s more to come. Regime leaders – esp...  Mike Pompeo
# 54  And you should know that the United States is ...  Mike Pompeo
# 55  Today, one in four Iranians – 14 million peopl...  Mike Pompeo
# 56  And finally – and finally, America is unafraid...  Mike Pompeo
# 57  We continue to raise our concerns over the Isl...  Mike Pompeo
# 58  And now we call on everyone here in the audien...  Mike Pompeo
# 59  The goal of our efforts is to one day see Iran...  Mike Pompeo
# 60  Iranians in America enjoy all the freedoms sec...  Mike Pompeo
# 61  There are a few individuals with us I want to ...  Mike Pompeo
# 62  Goli Ameri came to the United States as a fres...  Mike Pompeo
# 63  Susan Azizzadeh was forced to leave everything...  Mike Pompeo
# 64  Makan Delrahim – I think I saw him – came to A...  Mike Pompeo
# 65  We hope that the successes of Goli and Susan a...  Mike Pompeo
# 66  While it is ultimately up to the Iranian peopl...  Mike Pompeo
# 67  I thought I’d close tonight in a perfectly app...  Mike Pompeo
# 68  In 1982, President Reagan gave a speech to the...  Mike Pompeo
# 69  This is why we also call on all governments to...  Mike Pompeo
# 70  Today, the United States condemns oppression l...  Mike Pompeo
# 71  It’s America’s hope that the next 40 years of ...  Mike Pompeo
# 72                                        Thank you.   Mike Pompeo
#
# [847 rows x 2 columns]

# %%
# I want to remove punctuation from the text for word counting purposes
import string
no_punct_translator=str.maketrans('','',string.punctuation)

# tokenize each sentence and remove punctuation
train['words'] = train['text'].apply(lambda t: nltk.word_tokenize(t.translate(no_punct_translator).lower()))

# %%
train['word_count'] = train['words'].apply(lambda words: len(words))

# for normalization, how many characters per sentence w/o punctuation
train['sentence_length'] = train['words'].apply(lambda w: sum(map(len, w)))

# for future calculations, let's keep around the full text length, including punctuation
train['text_length'] = train['text'].apply(lambda t: len(t))

# %%
train.head()
# Out:
#                                                 text     author  \
# 0  Good evening, and sincere thanks to the Atlant...  Dan Coats
# 1  I enjoyed catching up with Atlantic council bo...  Dan Coats
# 2  Jeff Gedmin and I were also able to spend a fe...  Dan Coats
# 3  Last but certainly not least I would like to  ...  Dan Coats
# 4  So if you don’t like or agree with my remarks ...  Dan Coats
#
#                                                words  word_count  \
# 0  [good, evening, and, sincere, thanks, to, the,...          25
# 1  [i, enjoyed, catching, up, with, atlantic, cou...          32
# 2  [jeff, gedmin, and, i, were, also, able, to, s...          22
# 3  [last, but, certainly, not, least, i, would, l...          43
# 4  [so, if, you, don, ’, t, like, or, agree, with...          17
#
#    sentence_length  text_length
# 0              143          172
# 1              160          191
# 2               89          111
# 3              197          249
# 4               57           73

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x = "author", y = "word_count", data=train, color = "red",)

# %%
train.groupby(['author'])['word_count'].describe()
# Out:
#                   count       mean        std   min    25%    50%     75%  \
# author
# Dan Coats         100.0  22.930000   9.146678   2.0  17.00   22.0   28.00
# James Mattis       42.0  64.500000  44.683303   0.0  37.25   55.0   96.25
# John Kelly        434.0  14.101382   4.449755   0.0  13.00   15.0   16.00
# Kevin Hassett      72.0  80.763889  40.020239   1.0  57.00   77.0  102.25
# Kirstjen Nielsen   12.0  90.500000  58.324328  10.0  28.25  113.5  119.00
# Larry Kudlow       96.0  35.625000  20.325380   0.0  22.75   36.0   46.25
# Mike Pence         18.0  80.777778  65.596409   0.0  11.75   69.5  137.00
# Mike Pompeo        73.0  52.054795  31.078257   2.0  27.00   45.0   75.00
#
#                     max
# author
# Dan Coats          52.0
# James Mattis      212.0
# John Kelly         22.0
# Kevin Hassett     173.0
# Kirstjen Nielsen  185.0
# Larry Kudlow      126.0
# Mike Pence        189.0
# Mike Pompeo       127.0

# %%
train.groupby(['author'])['sentence_length'].describe()
# Out:
#                   count        mean         std   min     25%    50%     75%  \
# author
# Dan Coats         100.0  112.220000   44.415981   8.0   85.00  105.0  139.00
# James Mattis       42.0  285.142857  190.634444   0.0  156.00  264.5  430.50
# John Kelly        434.0   69.930876   19.178867   0.0   72.00   76.0   79.00
# Kevin Hassett      72.0  383.069444  191.233308   8.0  256.00  371.0  473.25
# Kirstjen Nielsen   12.0  512.166667  325.710366  41.0  167.00  635.5  684.00
# Larry Kudlow       96.0  162.947917   96.316405   0.0   97.25  172.5  212.50
# Mike Pence         18.0  375.055556  297.069307   0.0   57.50  374.0  620.50
# Mike Pompeo        73.0  239.780822  147.570628   8.0  125.00  214.0  325.00
#
#                     max
# author
# Dan Coats         248.0
# James Mattis      905.0
# John Kelly         87.0
# Kevin Hassett     852.0
# Kirstjen Nielsen  998.0
# Larry Kudlow      565.0
# Mike Pence        851.0
# Mike Pompeo       597.0

# %%
# the string library defines `string.punctuation` which is all the punctuation chars
train['punctuation_count'] = train['text'].apply(lambda t: len(list(filter(lambda c: c in t, string.punctuation))))

train['punctuation_per_char'] = train['punctuation_count'] / train['text_length'] 

train.groupby(['author'])['punctuation_per_char'].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# author
# Dan Coats         100.0  0.014638  0.010884  0.000000  0.009359  0.012308
# James Mattis       42.0  0.018040  0.039478  0.000000  0.005716  0.008032
# John Kelly        434.0  0.016620  0.016184  0.000000  0.010417  0.011111
# Kevin Hassett      72.0  0.007124  0.004551  0.000000  0.004602  0.006180
# Kirstjen Nielsen   12.0  0.016137  0.019963  0.002478  0.003830  0.004606
# Larry Kudlow       96.0  0.018307  0.015097  0.000000  0.010088  0.014035
# Mike Pence         18.0  0.005791  0.005048  0.000000  0.000747  0.005610
# Mike Pompeo        73.0  0.010362  0.011055  0.002740  0.005666  0.007653
#
#                        75%       max
# author
# Dan Coats         0.016879  0.100000
# James Mattis      0.012471  0.250000
# John Kelly        0.021505  0.142857
# Kevin Hassett     0.007909  0.026316
# Kirstjen Nielsen  0.023514  0.056604
# Larry Kudlow      0.018120  0.090909
# Mike Pence        0.008154  0.016349
# Mike Pompeo       0.011494  0.090909

# %%
train = train[train.word_count != 0]
train['word_count'].min()
# Out:
# 1

# %%
def unique_words(words):
    word_count = len(words)
    unique_count = len(set(words)) # creating a set from the list 'words' removes duplicates
    return unique_count / word_count

train['unique_ratio'] = train['words'].apply(unique_words)
train.groupby(['author'])['unique_ratio'].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# author
# Dan Coats         100.0  0.904796  0.078460  0.543478  0.856272  0.914855
# James Mattis       41.0  0.814833  0.105064  0.608491  0.765306  0.816667
# John Kelly        416.0  0.932414  0.069257  0.642857  0.888889  0.937500
# Kevin Hassett      72.0  0.769314  0.101863  0.533981  0.705953  0.763709
# Kirstjen Nielsen   12.0  0.756328  0.108446  0.600000  0.692033  0.727426
# Larry Kudlow       94.0  0.876899  0.091527  0.629630  0.819940  0.878418
# Mike Pence         17.0  0.753203  0.159794  0.549296  0.629630  0.720000
# Mike Pompeo        73.0  0.825792  0.094978  0.631579  0.750000  0.807692
#
#                        75%       max
# author
# Dan Coats         0.954545  1.000000
# James Mattis      0.888889  1.000000
# John Kelly        1.000000  1.000000
# Kevin Hassett     0.846480  1.000000
# Kirstjen Nielsen  0.815909  0.928571
# Larry Kudlow      0.953409  1.000000
# Mike Pence        0.828125  1.000000
# Mike Pompeo       0.880952  1.000000

# %% [markdown]
# Seems like the usage of unique words are about the same (90% of words are unique), though the distribution varies a bit. Let's graph the distribution of unique words for each author.

# %%
authors = ['Dan Coats', 'James Mattis', 'John Kelly','Kevin Hassett','Kirstjen Nielsen','Larry Kudlow',
          'Mike Pence','Mike Pompeo']

for author in authors:
    sns.distplot(train[train['author'] == author]['unique_ratio'], label = author, hist=False)

plt.legend();
# Out:
# /Users/Michael/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# add up the length of each words and devide by the total number of words
avg_length = lambda words: sum(map(len, words)) / len(words)

train['avg_word_length'] = train['words'].apply(avg_length)
train.groupby(['author'])['avg_word_length'].describe()
# Out:
#                   count      mean       std       min       25%       50%  \
# author
# Dan Coats         100.0  4.936993  0.742003  3.272727  4.396154  4.958059
# James Mattis       41.0  4.438753  0.471618  3.000000  4.290000  4.500000
# John Kelly        416.0  5.119119  0.963190  2.769231  4.529412  5.000000
# Kevin Hassett      72.0  4.787145  0.553818  3.642202  4.512500  4.815273
# Kirstjen Nielsen   12.0  5.640672  0.606120  4.100000  5.478814  5.651723
# Larry Kudlow       94.0  4.544532  0.718818  2.250000  4.113506  4.562539
# Mike Pence         17.0  5.272602  1.854075  4.245902  4.489655  4.609375
# Mike Pompeo        73.0  4.585461  0.424685  3.380952  4.297297  4.629630
#
#                        75%        max
# author
# Dan Coats         5.382919   7.333333
# James Mattis      4.666667   5.847826
# John Kelly        5.642857  10.000000
# Kevin Hassett     4.970737   8.000000
# Kirstjen Nielsen  5.949567   6.727273
# Larry Kudlow      5.000000   6.481481
# Mike Pence        5.169014  12.000000
# Mike Pompeo       4.877193   5.450000

# %%
for author in authors:
    sns.distplot(train[train['author'] == author]['avg_word_length'], label = author, hist=False)

plt.legend();
# Out:
# /Users/Michael/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Where we are now
# We have broken down the text into lots of different features, some which might be useful to feed into a machine learning algorithm. Let's see what we have:
#
# word_count: number of words in the average sentence
# sentence_length: number of word characters in each sentence
# text_length: pure number of characters, including spaces and punctuation
# punctuation_per_char: how often an author uses punctuation marks per character written
# unique_ration: ratio of unique words to total words
# avg_word_length: how many characters is in the average word written

# %% [markdown]
# Sentiment Analysis¶
#
# Now let's analyze the text itself for sentiment, hoping that some authors are more "positive", "neutral" or "negative" in their sentences than others. NTLK makes this pretty easy with the VADER sentiment analyzer (http://www.nltk.org/api/nltk.sentiment.html#module-nltk.sentiment.vader)

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

train['sentiment'] = train['text'].apply(lambda t: sid.polarity_scores(t)['compound'])
train.groupby('author')['sentiment'].describe()
# Out:
# /Users/Michael/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#                   count      mean       std     min     25%      50%      75%  \
# author
# Dan Coats         100.0  0.104498  0.484647 -0.9735 -0.2615  0.06400  0.47670
# James Mattis       41.0  0.161678  0.616022 -0.9723 -0.3182  0.29440  0.68870
# John Kelly        416.0 -0.036147  0.435986 -0.9217 -0.3612  0.00000  0.27320
# Kevin Hassett      72.0  0.333751  0.573724 -0.8779  0.0000  0.52615  0.80335
# Kirstjen Nielsen   12.0 -0.731208  0.201303 -0.9779 -0.9357 -0.75555 -0.51850
# Larry Kudlow       94.0  0.235424  0.460937 -0.8555  0.0000  0.27320  0.62490
# Mike Pence         17.0 -0.032812  0.616995 -0.9538 -0.5893  0.00000  0.25840
# Mike Pompeo        73.0  0.070937  0.682491 -0.9705 -0.6070  0.20230  0.76500
#
#                      max
# author
# Dan Coats         0.9042
# James Mattis      0.9578
# John Kelly        0.8979
# Kevin Hassett     0.9843
# Kirstjen Nielsen -0.4588
# Larry Kudlow      0.9643
# Mike Pence        0.9538
# Mike Pompeo       0.9771

# %%
for author in authors:
    sns.distplot(train[train['author'] == author]['sentiment'], label = author, hist=False)

plt.legend();
# Out:
# /Users/Michael/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x="author", y="sentiment", data=train);

# %% [markdown]
# Word Frequency
# I'd like to try to figure out if some authors have "favorite" words, which could help us determine which author wrote some specific piece of text.
#
# I'm not sure the best way to go about this, but I have a few ideas:
#
# Find the top N most commonly used words (for each author?), then score each text based on how frequently that word appears.
# issue: we would want to strip out common pronounds, conjunctions and other parts of speach
# issue: the ratio would probably be really close to zero so we'd want to normalize
# Pick a part of speach, say verbs or adverbs, and see how often certain authors utilize some array of top words
# issue: where would these words come from, should they just come from the whole training set?
# Instead of specific words, we could see how often authors use certain parts of speech using nltk

# %%
# Let's start by figuring out the most common words in our word dataset

# iterate all rows and create a new dataframe with author->word (single word)
df_words = pd.concat([pd.DataFrame(data={'author': [row['author'] for _ in row['words']], 'word': row['words']})
           for _, row in train.iterrows()], ignore_index=True)

# use NLTK to remove all rows with simple stop words
df_words = df_words[~df_words['word'].isin(nltk.corpus.stopwords.words('english'))]

df_words.shape
# Out:
# (14577, 2)

# %%
# let's use wordclouds to see which words each author likes to use
from wordcloud import WordCloud, STOPWORDS

def authorWordcloud(author):
    # lower max_font_size
    wordcloud = WordCloud(max_font_size=40,background_color="black", max_words=10000).generate(" ".join(df_words[df_words['author'] == author]['word'].values))
    plt.figure(figsize=(11,13))
    plt.title(author, fontsize=16)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    
    
authorWordcloud('Mike Pence')
authorWordcloud('John Kelly')
authorWordcloud('Larry Kudlow')

# %% [markdown]
# Now we have wordclouds for each author
# We can tell already that they tend to favor certain words, and they often intersect in interesting ways. Now let's try to figure out the most commonly used words by each author

# %%
# function for a specific author to count occurances of each word
def authorCommonWords(author, numWords):
    authorWords = df_words[df_words['author'] == author].groupby('word').size().reset_index().rename(columns={0:'count'})
    authorWords.sort_values('count', inplace=True)
    return authorWords[-numWords:]

# for example, here's how we get the 10 most common EAP words.
authorCommonWords('Mike Pence', 10)
authorCommonWords('Larry Kudlow', 10)
# Out:
#             word  count
# 693    president     13
# 313       energy     13
# 489   investment     13
# 795         said     16
# 1008           —     17
# 933        trump     25
# 895          tax     31
# 1011           “     44
# 1012           ”     44
# 1010           ’     72

# %% [markdown]
# Utilizing An Author's Top Words
# Now we can get a list of an author's top words, and there are probably lots of ways to use them. Our initial appoach will be make an indicator tensor (https://www.tensorflow.org/api_docs/python/tf/feature_column/indicator_column) for each possible top word and use it to indicate whether that example contains the given word. Then we'll let our ML algorithm figure out the scoring relationship by treating that column as categorical data.

# %%
# get all top words from our authors.
# this will represent our top words "vocabulary list"
authors_top_words = []
for author in authors:
    authors_top_words.extend(authorCommonWords(author, 10)['word'].values)

# use a set to remove duplicates
authors_top_words = list(set(authors_top_words))

# %%
train['top_words'] = train['words'].apply(lambda w: list(set(filter(set(w).__contains__, authors_top_words))))
train[['author','top_words', 'words']].head()
# Out:
#       author                  top_words  \
# 0  Dan Coats   [tocqueville, democracy]
# 1  Dan Coats  [president, executive, ’]
# 2  Dan Coats                    [–, us]
# 3  Dan Coats          [tocqueville, us]
# 4  Dan Coats                        [’]
#
#                                                words
# 0  [good, evening, and, sincere, thanks, to, the,...
# 1  [i, enjoyed, catching, up, with, atlantic, cou...
# 2  [jeff, gedmin, and, i, were, also, able, to, s...
# 3  [last, but, certainly, not, least, i, would, l...
# 4  [so, if, you, don, ’, t, like, or, agree, with...

# %% [markdown]
# Making an ML Model
# Now that we have a lot of features, let's try to make our first ML model and see how it does. I'm going to use Tensorflow to make a Logistic Regression model using the estimator API.
#
# Defining our features for Tensorflow
# We have both continuous value columns, like words per sentence, and some categorical columns like top_words. Let's figure out which columns we want to use from our dataframe and then define the feature columns.

# %%
# First, let's just pull out the columns we need
# feature_columns = ['author', 'word_count', 'text_length', 'punctuation_per_char', 'unique_ratio', 'avg_word_length', 'sentiment', 'top_words']
# TODO: put back in top_words once we figure it out
feature_columns = ['author', 'word_count', 'text_length', 'punctuation_per_char', 'unique_ratio', 'avg_word_length', 'sentiment']
df_features = train[feature_columns]

# Now let's split into a train and dev set
# use random_state seed so we get the same split each time
df_train=df_features.sample(frac=0.8,random_state=1)
df_dev=df_features.drop(df_train.index)

df_train.head()
# Out:
#            author  word_count  text_length  punctuation_per_char  \
# 48    Mike Pompeo          35          193              0.010363
# 218    John Kelly          16           95              0.010526
# 28   Larry Kudlow          52          255              0.015686
# 8       Dan Coats          25          180              0.011111
# 326    John Kelly          13           89              0.000000
#
#      unique_ratio  avg_word_length  sentiment
# 48       0.885714         4.485714     0.8834
# 218      0.812500         4.812500     0.4767
# 28       0.807692         3.884615     0.2135
# 8        0.760000         6.080000     0.4404
# 326      1.000000         5.923077    -0.8316

# %%
import tensorflow as tf
# Out:
# /Users/Michael/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# continual numeric features
feature_word_count = tf.feature_column.numeric_column("word_count")
feature_text_length = tf.feature_column.numeric_column("text_length")
feature_punctuation_per_char = tf.feature_column.numeric_column("punctuation_per_char")
feature_unique_ratio = tf.feature_column.numeric_column("unique_ratio")
feature_avg_word_length = tf.feature_column.numeric_column("avg_word_length")
feature_sentiment = tf.feature_column.numeric_column("sentiment")


base_columns = [
    feature_word_count, feature_text_length, feature_punctuation_per_char, feature_unique_ratio, feature_avg_word_length, feature_sentiment
]

# %%
import tempfile

model_dir = tempfile.mkdtemp() # base temp directory for running models

# our Y value labels, i.e. the thing we are classifying
labels_train = df_train['author']

# let's make a training function we can use with our estimators
train_fn = tf.estimator.inputs.pandas_input_fn(
    x=df_train,
    y=labels_train,
    batch_size=100,
    num_epochs=None, # unlimited
    shuffle=True, # shuffle the training data around
    num_threads=5)

# let's try a simple linear classifier
linear_model = tf.estimator.LinearClassifier(
    model_dir=model_dir, 
    feature_columns=base_columns,
    n_classes=len(authors),
    label_vocabulary=authors)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/vj/xsyxfhq96vn4tnxml49dtkww0000gn/T/tmpghgroshs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1a303d56a0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
train_steps = 5000

# now let's train that model!
linear_model.train(input_fn=train_fn, steps=train_steps)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/vj/xsyxfhq96vn4tnxml49dtkww0000gn/T/tmpghgroshs/model.ckpt.
# INFO:tensorflow:loss = 207.94412, step = 1
# INFO:tensorflow:global_step/sec: 191.623
# INFO:tensorflow:loss = 286.85983, step = 101 (0.522 sec)
# INFO:tensorflow:global_step/sec: 263.854
# INFO:tensorflow:loss = 393.8315, step = 201 (0.379 sec)
# INFO:tensorflow:global_step/sec: 276.054
# INFO:tensorflow:loss = 295.23764, step = 301 (0.362 sec)
# INFO:tensorflow:global_step/sec: 265.003
# INFO:tensorflow:loss = 138.41365, step = 401 (0.377 sec)
# INFO:tensorflow:global_step/sec: 218.573
# INFO:tensorflow:loss = 174.99742, step = 501 (0.457 sec)
# INFO:tensorflow:global_step/sec: 182.71
# INFO:tensorflow:loss = 225.84866, step = 601 (0.547 sec)
# INFO:tensorflow:global_step/sec: 265.049
# INFO:tensorflow:loss = 115.149666, step = 701 (0.377 sec)
# INFO:tensorflow:global_step/sec: 212.948
# INFO:tensorflow:loss = 176.46909, step = 801 (0.470 sec)
# INFO:tensorflow:global_step/sec: 268.808
# INFO:tensorflow:loss = 148.54344, step = 901 (0.372 sec)
# INFO:tensorflow:global_step/sec: 255.709
# INFO:tensorflow:loss = 134.96793, step = 1001 (0.391 sec)
# INFO:tensorflow:global_step/sec: 263.847
# INFO:tensorflow:loss = 140.86595, step = 1101 (0.379 sec)
# INFO:tensorflow:global_step/sec: 268.423
# INFO:tensorflow:loss = 107.65486, step = 1201 (0.373 sec)
# INFO:tensorflow:global_step/sec: 269.036
# INFO:tensorflow:loss = 130.84799, step = 1301 (0.372 sec)
# INFO:tensorflow:global_step/sec: 266.929
# INFO:tensorflow:loss = 145.87495, step = 1401 (0.375 sec)
# INFO:tensorflow:global_step/sec: 267.183
# INFO:tensorflow:loss = 129.32747, step = 1501 (0.374 sec)
# INFO:tensorflow:global_step/sec: 271.742
# INFO:tensorflow:loss = 102.38065, step = 1601 (0.368 sec)
# INFO:tensorflow:global_step/sec: 265.17
# INFO:tensorflow:loss = 120.48183, step = 1701 (0.377 sec)
# INFO:tensorflow:global_step/sec: 268.833
# INFO:tensorflow:loss = 136.00508, step = 1801 (0.372 sec)
# INFO:tensorflow:global_step/sec: 265.704
# INFO:tensorflow:loss = 110.19869, step = 1901 (0.376 sec)
# INFO:tensorflow:global_step/sec: 266.127
# INFO:tensorflow:loss = 105.623276, step = 2001 (0.376 sec)
# INFO:tensorflow:global_step/sec: 274.139
# INFO:tensorflow:loss = 151.5279, step = 2101 (0.365 sec)
# INFO:tensorflow:global_step/sec: 272.543
# INFO:tensorflow:loss = 125.779106, step = 2201 (0.367 sec)
# INFO:tensorflow:global_step/sec: 247.437
# INFO:tensorflow:loss = 106.57391, step = 2301 (0.405 sec)
# INFO:tensorflow:global_step/sec: 186.402
# INFO:tensorflow:loss = 103.875786, step = 2401 (0.536 sec)
# INFO:tensorflow:global_step/sec: 188.396
# INFO:tensorflow:loss = 113.17241, step = 2501 (0.529 sec)
# INFO:tensorflow:global_step/sec: 202.371
# INFO:tensorflow:loss = 116.19021, step = 2601 (0.494 sec)
# INFO:tensorflow:global_step/sec: 254.253
# INFO:tensorflow:loss = 108.58735, step = 2701 (0.394 sec)
# INFO:tensorflow:global_step/sec: 210.111
# INFO:tensorflow:loss = 152.56279, step = 2801 (0.480 sec)
# INFO:tensorflow:global_step/sec: 165.021
# INFO:tensorflow:loss = 137.12686, step = 2901 (0.603 sec)
# INFO:tensorflow:global_step/sec: 167.473
# INFO:tensorflow:loss = 100.555145, step = 3001 (0.598 sec)
# INFO:tensorflow:global_step/sec: 200.505
# INFO:tensorflow:loss = 125.600044, step = 3101 (0.497 sec)
# INFO:tensorflow:global_step/sec: 204.593
# INFO:tensorflow:loss = 122.888504, step = 3201 (0.489 sec)
# INFO:tensorflow:global_step/sec: 204.919
# INFO:tensorflow:loss = 100.34511, step = 3301 (0.488 sec)
# INFO:tensorflow:global_step/sec: 217.013
# INFO:tensorflow:loss = 129.59982, step = 3401 (0.461 sec)
# INFO:tensorflow:global_step/sec: 234.654
# INFO:tensorflow:loss = 131.4317, step = 3501 (0.426 sec)
# INFO:tensorflow:global_step/sec: 269.713
# INFO:tensorflow:loss = 103.756546, step = 3601 (0.371 sec)
# INFO:tensorflow:global_step/sec: 235.76
# INFO:tensorflow:loss = 100.39705, step = 3701 (0.424 sec)
# INFO:tensorflow:global_step/sec: 252.731
# INFO:tensorflow:loss = 119.657135, step = 3801 (0.396 sec)
# INFO:tensorflow:global_step/sec: 263.478
# INFO:tensorflow:loss = 108.703224, step = 3901 (0.380 sec)
# INFO:tensorflow:global_step/sec: 261.08
# INFO:tensorflow:loss = 104.90027, step = 4001 (0.383 sec)
# INFO:tensorflow:global_step/sec: 265.272
# INFO:tensorflow:loss = 109.59688, step = 4101 (0.377 sec)
# INFO:tensorflow:global_step/sec: 256.856
# INFO:tensorflow:loss = 100.526146, step = 4201 (0.389 sec)
# INFO:tensorflow:global_step/sec: 274.518
# INFO:tensorflow:loss = 120.51305, step = 4301 (0.364 sec)
# INFO:tensorflow:global_step/sec: 226.727
# INFO:tensorflow:loss = 116.156204, step = 4401 (0.441 sec)
# INFO:tensorflow:global_step/sec: 267.977
# INFO:tensorflow:loss = 103.94442, step = 4501 (0.373 sec)
# INFO:tensorflow:global_step/sec: 258.348
# INFO:tensorflow:loss = 127.83637, step = 4601 (0.387 sec)
# INFO:tensorflow:global_step/sec: 266.125
# INFO:tensorflow:loss = 116.51107, step = 4701 (0.376 sec)
# INFO:tensorflow:global_step/sec: 234.012
# INFO:tensorflow:loss = 115.35682, step = 4801 (0.427 sec)
# INFO:tensorflow:global_step/sec: 218.044
# INFO:tensorflow:loss = 107.519135, step = 4901 (0.459 sec)
# INFO:tensorflow:Saving checkpoints for 5000 into /var/folders/vj/xsyxfhq96vn4tnxml49dtkww0000gn/T/tmpghgroshs/model.ckpt.
# INFO:tensorflow:Loss for final step: 91.994965.

# %%
print((linear_model))
# Out:
# <tensorflow.python.estimator.canned.linear.LinearClassifier object at 0x1a303d52b0>

# %%
# let's see how well we did on our training set
dev_test_fn = tf.estimator.inputs.pandas_input_fn(
    x=df_dev,
    y=df_dev['author'],
    batch_size=100,
    num_epochs=1, # just one run
    shuffle=False, # don't shuffle test here
    num_threads=5)

linear_model.evaluate(input_fn=dev_test_fn)
# Out:
# WARNING:tensorflow:enqueue_data was called with num_epochs and num_threads > 1. num_epochs is applied per thread, so this will produce more epochs than you probably intend. If you want to limit epochs, use one thread.
# WARNING:tensorflow:enqueue_data was called with shuffle=False and num_threads > 1. This will create multiple threads, all reading the array/dataframe in order. If you want examples read in order, use one thread; if you want multiple threads, enable shuffling.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-30-02:22:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/vj/xsyxfhq96vn4tnxml49dtkww0000gn/T/tmpghgroshs/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-30-02:22:20
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 1.0, average_loss = 0.18673974, global_step = 5000, loss = 15.172605
# {'accuracy': 1.0,
#  'average_loss': 0.18673974,
#  'global_step': 5000,
#  'loss': 15.172605}

# %%
#Test the Model


opEd = pd.read_table("OpEd.txt", header =None)
opEd.columns = ['text']

# I want to remove punctuation from the text for word counting purposes
import string
no_punct_translator=str.maketrans('','',string.punctuation)

# tokenize each sentence and remove punctuation
opEd['words'] = opEd['text'].apply(lambda t: nltk.word_tokenize(t.translate(no_punct_translator).lower()))
opEd['word_count'] = opEd['words'].apply(lambda words: len(words))

# for normalization, how many characters per sentence w/o punctuation
opEd['sentence_length'] = opEd['words'].apply(lambda w: sum(map(len, w)))

# for future calculations, let's keep around the full text length, including punctuation
opEd['text_length'] = opEd['text'].apply(lambda t: len(t))
# the string library defines `string.punctuation` which is all the punctuation chars
opEd['punctuation_count'] = opEd['text'].apply(lambda t: len(list(filter(lambda c: c in t, string.punctuation))))

opEd['punctuation_per_char'] = opEd['punctuation_count'] / opEd['text_length'] 
opEd['unique_ratio'] = opEd['words'].apply(unique_words)
opEd['avg_word_length'] = opEd['words'].apply(avg_length)
sid = SentimentIntensityAnalyzer()

opEd['sentiment'] = opEd['text'].apply(lambda t: sid.polarity_scores(t)['compound'])


opEd.head()
# Out:
#                                                 text  \
# 0  I Am Part of the Resistance Inside the Trump A...
# 1  I work for the president but like-minded colle...
# 2  President Trump is facing a test to his presid...
# 3  It’s not just that the special counsel looms l...
# 4  The dilemma — which he does not fully grasp — ...
#
#                                                words  word_count  \
# 0  [i, am, part, of, the, resistance, inside, the...          10
# 1  [i, work, for, the, president, but, likeminded...          22
# 2  [president, trump, is, facing, a, test, to, hi...          17
# 3  [it, ’, s, not, just, that, the, special, coun...          41
# 4  [the, dilemma, —, which, he, does, not, fully,...          36
#
#    sentence_length  text_length  punctuation_count  punctuation_per_char  \
# 0               50           59                  0              0.000000
# 1              103          126                  2              0.015873
# 2               79           96                  1              0.010417
# 3              172          212                  1              0.004717
# 4              168          204                  1              0.004902
#
#    unique_ratio  avg_word_length  sentiment
# 0      0.900000         5.000000     0.0000
# 1      0.863636         4.681818    -0.7684
# 2      0.941176         4.647059     0.0000
# 3      0.804878         4.195122     0.0516
# 4      0.861111         4.666667    -0.8316

# %%
feature_columns = ['word_count', 'text_length', 'punctuation_per_char', 'unique_ratio', 'avg_word_length', 'sentiment']
testFeatures = opEd[feature_columns]

# continual numeric features
feature_word_count = tf.feature_column.numeric_column("word_count")
feature_text_length = tf.feature_column.numeric_column("text_length")
feature_punctuation_per_char = tf.feature_column.numeric_column("punctuation_per_char")
feature_unique_ratio = tf.feature_column.numeric_column("unique_ratio")
feature_avg_word_length = tf.feature_column.numeric_column("avg_word_length")
feature_sentiment = tf.feature_column.numeric_column("sentiment")


base_columns = [
    feature_word_count, feature_text_length, feature_punctuation_per_char, feature_unique_ratio, feature_avg_word_length, feature_sentiment
]

# %%
testFeatures.shape
# Out:
# (27, 6)

# %%
test_fn = tf.estimator.inputs.pandas_input_fn(
    x=testFeatures,
    batch_size=27,
    num_epochs=100, # unlimited
    shuffle=True, # shuffle the training data around
    num_threads=5)
predictions = linear_model.predict(input_fn=test_fn)



#print(linear_model.predict(input_fn=test_fn))

# %%
x = [predictions.__next__()['classes'] for i in range(27)]

g = []
for i in x:
    g.append(i[0].decode('utf-8'))

   
predictionSeries = pd.Series(g)
predictionSeries.hist()
# Out:
# WARNING:tensorflow:enqueue_data was called with num_epochs and num_threads > 1. num_epochs is applied per thread, so this will produce more epochs than you probably intend. If you want to limit epochs, use one thread.
# WARNING:tensorflow:enqueue_data was called with shuffle=True, num_threads > 1, and num_epochs. This will create multiple threads, all reading the array/dataframe in order adding to the same shuffling queue; the results will likely not be sufficiently shuffled.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/vj/xsyxfhq96vn4tnxml49dtkww0000gn/T/tmpghgroshs/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
[predictions.__next__()['classes'] for i in range(1)]
# Out:
# [array([b'John Kelly'], dtype=object)]
